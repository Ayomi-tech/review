# %%
# !pip3 install apache beam
# Out:
# ERROR: Could not find a version that satisfies the requirement apache (from versions: none)
# ERROR: No matching distribution found for apache
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
pip install --upgrade pip apache beam
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement apache (from versions: none)
# ERROR: No matching distribution found for apache
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install apache_beam
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 898.7 kB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 803.4 kB/s eta 0:00:00 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 1.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.4/792.4 kB 1.4 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 744.2 kB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 642.2 kB/s eta 0:00:00 0:00:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 1.5 MB/s eta 0:00:0000:0100:01
# ...

# %%
pip install --upgrade pip apache_beam
# Out:
# ...
#   Using cached pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached apache_beam-2.48.0-cp37-cp37m-macosx_10_9_x86_64.whl.metadata (6.2 kB)
# ...
#   Using cached crcmod-1.7-cp37-cp37m-macosx_10_9_x86_64.whl
# ...
#   Using cached orjson-3.9.7-cp37-cp37m-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
# ...
#   Using cached dill-0.3.1.1-py3-none-any.whl
# ...
#   Using cached cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached fastavro-1.8.0.tar.gz (792 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached grpcio-1.62.2-cp37-cp37m-macosx_10_10_universal2.whl.metadata (4.0 kB)
# ...
#   Using cached hdfs-2.7.3-py3-none-any.whl
# ...
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached objsize-0.6.1-py3-none-any.whl.metadata (10 kB)
# ...

# %%
import apache_beam as beam
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-da823551e0e3> in <module>
# ----> 1 import apache_beam as beam
#
# ModuleNotFoundError: No module named 'apache_beam'
