# %%
pip install apache-beam
# Out:
# ...
#   Using cached apache_beam-2.48.0-cp37-cp37m-macosx_10_9_x86_64.whl.metadata (6.2 kB)
# ...
#   Using cached crcmod-1.7-cp37-cp37m-macosx_10_9_x86_64.whl
# ...
#   Using cached orjson-3.9.7-cp37-cp37m-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
# ...
#   Using cached dill-0.3.1.1-py3-none-any.whl
# ...
#   Using cached cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached fastavro-1.8.0.tar.gz (792 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached grpcio-1.62.2-cp37-cp37m-macosx_10_10_universal2.whl.metadata (4.0 kB)
# ...
#   Using cached hdfs-2.7.3-py3-none-any.whl
# ...
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached objsize-0.6.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached pymongo-4.6.3-cp37-cp37m-macosx_10_6_intel.whl.metadata (22 kB)
# ...

# %%
pip install 'apache-beam[fastavro]'
# Out:
# ...
#   Using cached apache_beam-2.48.0-cp37-cp37m-macosx_10_9_x86_64.whl.metadata (6.2 kB)
# WARNING: apache-beam 2.48.0 does not provide the extra 'fastavro'
# ...
#   Using cached crcmod-1.7-cp37-cp37m-macosx_10_9_x86_64.whl
# ...
#   Using cached orjson-3.9.7-cp37-cp37m-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
# ...
#   Using cached dill-0.3.1.1-py3-none-any.whl
# ...
#   Using cached cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached fastavro-1.8.0.tar.gz (792 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached grpcio-1.62.2-cp37-cp37m-macosx_10_10_universal2.whl.metadata (4.0 kB)
# ...
#   Using cached hdfs-2.7.3-py3-none-any.whl
# ...
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached objsize-0.6.1-py3-none-any.whl.metadata (10 kB)
# ...

# %%
import sys
print(sys.version)
# Out:
# 3.7.6 (default, Jan  8 2020, 13:42:34)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
